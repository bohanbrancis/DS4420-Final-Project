# %%
import nfl_data_py as nfl

# %%
seasons = [2024]
inj = nfl.import_injuries(seasons)

# %%
# Out:
# 0       Oblique
# 1          Back
# 2         Ankle
# 3          None
# 4          None
#          ...
# 6210       None
# 6211       Neck
# 6212      Elbow
# 6213    Abdomen
# 6214      Groin
# Name: report_primary_injury, Length: 6215, dtype: object

# %%
weekly = nfl.import_weekly_data(seasons)
# Out:
# Downcasting floats.

# %%
weekly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5597 entries, 0 to 5596
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   player_id                    5597 non-null   object
#  1   player_name                  5597 non-null   object
#  2   player_display_name          5597 non-null   object
#  3   position                     5597 non-null   object
#  4   position_group               5597 non-null   object
#  5   headshot_url                 5597 non-null   object
#  6   recent_team                  5597 non-null   object
#  7   season                       5597 non-null   int32
#  8   week                         5597 non-null   int32
#  9   season_type                  5597 non-null   object
#  10  opponent_team                5597 non-null   object
#  11  completions                  5597 non-null   int32
#  12  attempts                     5597 non-null   int32
# ...
